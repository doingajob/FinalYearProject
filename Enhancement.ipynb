# %% [markdown]
# <a href="https://colab.research.google.com/github/doingajob/FinalYearProject/blob/main/Enhancement.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# %tensorflow_version 1.x
import tensorflow as tf
import numpy
import PIL
# Out:
# TensorFlow 1.x selected.

# %%
from google.colab import drive
drive.mount('/content/gdrive')

# !ln -s /content/gdrive/My\ Drive/ /mydrive
# Out:
# Mounted at /content/gdrive

# %%
print(tf.__version__)
# Out:
# 1.15.2

# %%
# !git clone https://github.com/weichen582/RetinexNet
# Out:
# Cloning into 'RetinexNet'...
# remote: Enumerating objects: 51, done.
# remote: Total 51 (delta 0), reused 0 (delta 0), pack-reused 51
# Unpacking objects: 100% (51/51), done.

# %%
# %cd /content
# !mkdir valid
# !mkdir test

# %cd ./valid
# !unzip /mydrive/LaribDBtestdata.zip -d images
# !unzip /mydrive/LaribDBlabels.zip  -d labels

# %cd ../test
# !unzip /mydrive/ColonDBJPGs.zip -d images
# !unzip /mydrive/ColonDBLabels.zip -d labels
# Out:
# /content
# /content/valid
# Archive:  /mydrive/LaribDBtestdata.zip
#   inflating: images/1.tif
#   inflating: images/10.tif
#   inflating: images/100.tif
#   inflating: images/101.tif
#   inflating: images/102.tif
#   inflating: images/103.tif
#   inflating: images/104.tif
#   inflating: images/105.tif
#   inflating: images/106.tif
#   inflating: images/107.tif
#   inflating: images/108.tif
#   inflating: images/109.tif
#   inflating: images/11.tif
#   inflating: images/110.tif
#   inflating: images/111.tif
#   inflating: images/112.tif
#   inflating: images/113.tif
#   inflating: images/114.tif
#   inflating: images/115.tif
#   inflating: images/116.tif
#   inflating: images/117.tif
#   inflating: images/118.tif
#   inflating: images/119.tif
#   inflating: images/12.tif
#   inflating: images/120.tif
#   inflating: images/121.tif
#   inflating: images/122.tif
#   inflating: images/123.tif
#   inflating: images/124.tif
#   inflating: images/125.tif
#   inflating: images/126.tif
# ...

# %%
# %cd /content
# !mkdir results
# Out:
# /content

# %%
# %cd RetinexNet
# !python main.py --use_gpu=1 --gpu_idx=0 --gpu_mem=0.5 --phase=test --test_dir=/mydrive/JPGs --save_dir=/content/results --decom=1
# Out:
# /content/RetinexNet
# WARNING:tensorflow:From main.py:117: The name tf.app.run is deprecated. Please use tf.compat.v1.app.run instead.
#
# [*] GPU
#
# WARNING:tensorflow:From main.py:94: The name tf.GPUOptions is deprecated. Please use tf.compat.v1.GPUOptions instead.
#
# W0408 15:22:21.475406 140475377780608 module_wrapper.py:139] From main.py:94: The name tf.GPUOptions is deprecated. Please use tf.compat.v1.GPUOptions instead.
#
# WARNING:tensorflow:From main.py:95: The name tf.Session is deprecated. Please use tf.compat.v1.Session instead.
#
# W0408 15:22:21.475660 140475377780608 module_wrapper.py:139] From main.py:95: The name tf.Session is deprecated. Please use tf.compat.v1.Session instead.
#
# WARNING:tensorflow:From main.py:95: The name tf.ConfigProto is deprecated. Please use tf.compat.v1.ConfigProto instead.
#
# W0408 15:22:21.475790 140475377780608 module_wrapper.py:139] From main.py:95: The name tf.ConfigProto is deprecated. Please use tf.compat.v1.ConfigProto instead.
# ...

# %%
# %cd /mydrive
# !mkdir JPGsenhanced

# !cp /content/results/* /mydrive/JPGsenhanced
# Out:
# /content/gdrive/My Drive

# %%
import glob
print(len(glob.glob('/mydrive/JPGsenhanced/*')))
# Out:
# 600
